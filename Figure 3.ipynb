# %%
# EIGENSPECTRA/SPECTRAL RADIUS EXPLORATOR


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import special
from scipy.stats import norm
from scipy.stats import pearsonr

import networkx as nx
import numpy as np
import pandas as pd



T = 1
N=100#number of neurons
N2 =100
d=-1
dt=0.1
beta=50 #gain of Gaussian
B=-0.05


#zero mean corrected connectivity matrix 
rho =0.05 #connectoin probability
f=0.8#proportion of e vs i cells/cortical
sigma_e_2 = 0.005
sigma_i_2 = 0.005
#AXEL: INCREASE MU_E TO INCREASE INSTABILITY AND FLUCTUATIONS AMPLITUDE
mu_e= 0.08 # so that the variance scales like 1/N
mu_i= -f/(1-f)*mu_e
S_o1 = 0.0

W = np.zeros((N,N))
M_e=np.random.normal(mu_e, np.sqrt(sigma_e_2), size=(N,N))
M_i=np.random.normal(mu_i, np.sqrt(sigma_i_2), size=(N,N))

List = np.zeros(N);
for i in range(N):
  for j in range(N):
    P_connectivity = np.random.rand()
    if (P_connectivity<rho):
      if (j<int(f*N)):
        List[j] = M_e[i][j];
      else:
        List[j] = M_i[i][j];
    else:
      List[j] = 0;
  np.random.shuffle(List)  
  for j in range(N):
    if i==j:
      W[i][j]=0
    else:
      W[i][j]=List[j]
row_sum=np.zeros(N)
for i in range(N):
  row_sum[i] =(np.sum(W[i][:]))
  number_of_nonzero_entries=0
  for j in range(N):
    if W[i][j]!=0:
      number_of_nonzero_entries = number_of_nonzero_entries+1
  for j in range(N):
    if W[i][j]!=0:  
      W[i][j]=W[i][j]-row_sum[i]/number_of_nonzero_entries



#zero mean corrected connectivity matrix 
rho2 =0.05 #connectoin probability
f2=0.8#proportion of e vs i cells/cortical
sigma_e_22 = 0.005
sigma_i_22 = 0.005
#AXEL: INCREASE MU_E TO INCREASE INSTABILITY AND FLUCTUATIONS AMPLITUDE
mu_e2= 0.08 # so that the variance scales like 1/N
mu_i2= -f2/(1-f2)*mu_e2
S_o2=0.025


W2 = np.zeros((N2,N2))
M_e2=np.random.normal(mu_e2, np.sqrt(sigma_e_22), size=(N2,N2))
M_i2=np.random.normal(mu_i2, np.sqrt(sigma_i_22), size=(N2,N2))

List2 = np.zeros(N2);
for i in range(N2):
  for j in range(N2):
    P_connectivity = np.random.rand()
    if (P_connectivity<rho2):
      if (j<int(f2*N2)):
        List2[j] = M_e2[i][j];
      else:
        List2[j] = M_i2[i][j];
    else:
      List2[j] = 0;
  np.random.shuffle(List2)  
  for j in range(N2):
    if i==j:
      W2[i][j]=0
    else:
      W2[i][j]=List2[j]
row_sum2=np.zeros(N2)
for i in range(N2):
  row_sum2[i] =(np.sum(W2[i][:]))
  number_of_nonzero_entries2=0
  for j in range(N2):
    if W2[i][j]!=0:
      number_of_nonzero_entries2 = number_of_nonzero_entries2+1
  for j in range(N2):
    if W2[i][j]!=0:  
      W2[i][j]=W2[i][j]-row_sum2[i]/number_of_nonzero_entries2


#variance connectivity matrix - scales like 1/N by construction
sigma_2 = rho*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*mu_e**2)
sigma_22 = rho2*(f2*sigma_e_22+(1-f2)*sigma_i_22+f2/(1-f2)*mu_e2**2)
# print(W)
# print(np.var(W),sigma_2)
# print(np.mean(W))
# for i in range(N):
#   print(np.sum(W[i][:]))

#zero mean corrected connectivity matrix 
N3=100
rho3 =0.05 #connectoin probability
f3=0.8#proportion of e vs i cells/cortical
sigma_e_23 = 0.005
sigma_i_23 = 0.005
#AXEL: INCREASE MU_E TO INCREASE INSTABILITY AND FLUCTUATIONS AMPLITUDE
mu_e3= 0.08 # so that the variance scales like 1/N
mu_i3= -f3/(1-f3)*mu_e3
S_o3=0.05


W3 = np.zeros((N3,N3))
M_e3=np.random.normal(mu_e3, np.sqrt(sigma_e_23), size=(N3,N3))
M_i3=np.random.normal(mu_i3, np.sqrt(sigma_i_23), size=(N3,N3))

List3 = np.zeros(N3);
for i in range(N3):
  for j in range(N3):
    P_connectivity = np.random.rand()
    if (P_connectivity<rho3):
      if (j<int(f3*N3)):
        List3[j] = M_e3[i][j];
      else:
        List3[j] = M_i3[i][j];
    else:
      List3[j] = 0;
  np.random.shuffle(List3)  
  for j in range(N3):
    if i==j:
      W3[i][j]=0
    else:
      W3[i][j]=List3[j]
row_sum3=np.zeros(N3)
for i in range(N3):
  row_sum3[i] =(np.sum(W3[i][:]))
  number_of_nonzero_entries3=0
  for j in range(N3):
    if W3[i][j]!=0:
      number_of_nonzero_entries3 = number_of_nonzero_entries3+1
  for j in range(N3):
    if W3[i][j]!=0:  
      W3[i][j]=W3[i][j]-row_sum3[i]/number_of_nonzero_entries3




#Jacobian
J_o = np.zeros((N,N))
J_o2 = np.zeros((N2,N2))
J_o3 = np.zeros((N3,N3))
J = np.zeros((N,N))
for i in range(N):
  for j in range(N):
    J_o[i][j] = W[i][j]*beta/np.sqrt(np.pi)*np.exp(-beta**2*(S_o1+B)**2)

Var_J_o = np.var(J_o)

for i in range(N2):
  for j in range(N2):
    J_o2[i][j] = W2[i][j]*beta/np.sqrt(np.pi)*np.exp(-beta**2*(S_o2+B)**2)

Var_J_o2 = np.var(J_o2)

for i in range(N3):
  for j in range(N3):
    J_o3[i][j] = W3[i][j]*beta/np.sqrt(np.pi)*np.exp(-beta**2*(S_o3+B)**2)

Var_J_o3 = np.var(J_o3)

#spectral radius
rad_o = np.sqrt(N*Var_J_o)
rad_o_theo = np.sqrt(N*sigma_2*beta**2/(np.pi*np.sqrt(4*0*beta**2+1))*(np.exp(-beta**2*(S_o1+B)**2))**2)

#spectral radius
rad_o2 = np.sqrt(N2*Var_J_o2)
rad_o_theo2 = np.sqrt(N2*sigma_2*beta**2/(np.pi*np.sqrt(4*0.*beta**2+1))*(np.exp(-beta**2*(S_o2+B)**2))**2)


#spectral radius
rad_o3 = np.sqrt(N3*Var_J_o3)
rad_o_theo3 = np.sqrt(N3*sigma_2*beta**2/(np.pi*np.sqrt(4*0.*beta**2+1))*(np.exp(-beta**2*(S_o3+B)**2))**2)

#extract eigenspectrum

eigenvalues_o = np.linalg.eigvals(J_o)# assuming trivial fixed points
X_o=eigenvalues_o.real
Y_o=eigenvalues_o.imag
eigenvalues_o2 = np.linalg.eigvals(J_o2)# assuming trivial fixed points
X_o2=eigenvalues_o2.real
Y_o2=eigenvalues_o2.imag
eigenvalues_o3 = np.linalg.eigvals(J_o3)# assuming trivial fixed points
X_o3=eigenvalues_o3.real
Y_o3=eigenvalues_o3.imag
plt.figure(figsize=(10,10))
x=np.arange(-15,15,0.01)
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
# plt.plot(x,np.sqrt(rad**2-(x-d)**2),color='black')
# plt.plot(x,-np.sqrt(rad**2-(x-d)**2),color= 'black')
# plt.plot(x,np.sqrt(rad_theo**2-(x-d)**2),color='red')
# plt.plot(x,-np.sqrt(rad_theo**2-(x-d)**2),color= 'red')
# plt.plot(x,np.sqrt(rad_o**2-(x-d)**2),color='black')
# plt.plot(x,-np.sqrt(rad_o**2-(x-d)**2),color= 'black')
plt.plot(x,np.sqrt(rad_o_theo**2-(x-d)**2),color='black',linewidth=3)
plt.plot(x,-np.sqrt(rad_o_theo**2-(x-d)**2),color= 'black',linewidth=3)
plt.plot(x,np.sqrt(rad_o_theo2**2-(x-d)**2),color='black',linewidth=3)
plt.plot(x,-np.sqrt(rad_o_theo2**2-(x-d)**2),color= 'black',linewidth=3)
plt.plot(x,np.sqrt(rad_o_theo3**2-(x-d)**2),color='black',linewidth=3)
plt.plot(x,-np.sqrt(rad_o_theo3**2-(x-d)**2),color= 'black',linewidth=3)
plt.scatter(X_o2+d,Y_o2, color='black',alpha=0.2,linewidth=3)
plt.scatter(X_o3+d,Y_o3, color='black',alpha=0.2,linewidth=3)
plt.scatter(X_o+d,Y_o, color='black',alpha=0.2,linewidth=3)
plt.xlim(-15,15,25)
plt.ylim(-15,15,25)
plt.axvline(x=0,color='k', linestyle='--')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:229: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:230: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:231: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:232: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:233: RuntimeWarning: invalid value encountered in sqrt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:234: RuntimeWarning: invalid value encountered in sqrt

# %%
#computing the spectral radius vs input amplitude S_o #RESET RUNTIME!!!!!
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import special
from scipy.stats import norm
from scipy.stats import pearsonr

import networkx as nx
import numpy as np
import pandas as pd




N=100#number of neurons
d=-1
dt=0.1
beta=50 #gain of Gaussian
sigma_h=0.0
B=-0.05

#zero mean corrected connectivity matrix 
rho =0.05 #connectoin probability
f=0.8#proportion of e vs i cells/cortical
sigma_e_2 = 0.005
sigma_i_2 = 0.005
#AXEL: INCREASE MU_E TO INCREASE INSTABILITY AND FLUCTUATIONS AMPLITUDE
mu_e= 0.08 # so that the variance scales like 1/N
mu_i= -f/(1-f)*mu_e
S_o1 = 0
sigma_2 = rho*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*mu_e**2)

W = np.zeros((N,N))
M_e=np.random.normal(mu_e, np.sqrt(sigma_e_2), size=(N,N))
M_i=np.random.normal(mu_i, np.sqrt(sigma_i_2), size=(N,N))

List = np.zeros(N);
for i in range(N):
  for j in range(N):
    P_connectivity = np.random.rand()
    if (P_connectivity<rho):
      if (j<int(f*N)):
        List[j] = M_e[i][j];
      else:
        List[j] = M_i[i][j];
    else:
      List[j] = 0;
  np.random.shuffle(List)  
  for j in range(N):
    if i==j:
      W[i][j]=0
    else:
      W[i][j]=List[j]
row_sum=np.zeros(N)
for i in range(N):
  row_sum[i] =(np.sum(W[i][:]))
  number_of_nonzero_entries=0
  for j in range(N):
    if W[i][j]!=0:
      number_of_nonzero_entries = number_of_nonzero_entries+1
  for j in range(N):
    if W[i][j]!=0:  
      W[i][j]=W[i][j]-row_sum[i]/number_of_nonzero_entries


S = np.arange(-0.1,0.1,0.001)
Spectral_radius = np.zeros(len(S))
Spectral_radius_theo =  np.zeros(len(S))
Spectral_radius_theo_hetero = np.zeros(len(S))
for s in range(len(S)):
  J_o = np.zeros((N,N))
  for i in range(N):
    for j in range(N):
      J_o[i][j] = W[i][j]*beta/np.sqrt(np.pi)*np.exp(-beta**2*(S[s]+B)**2)
  Var_J_o = np.var(J_o)
  Spectral_radius[s] = np.sqrt(N*Var_J_o)
  Spectral_radius_theo[s] = np.sqrt(N*sigma_2*beta**2/(np.pi*np.sqrt(4*0*beta**2+1))*np.exp(-2*beta**2*(S[s]+B)**2))
  Spectral_radius_theo_hetero[s] = np.sqrt(N*sigma_2*beta**2/(np.pi*np.sqrt(4*sigma_h*beta**2+1))*np.exp(-2*beta**2*(S[s]+B)**2/(1+4*beta**2*sigma_h)))


plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(S,Spectral_radius,color="blue",linewidth=4)
plt.plot(S,Spectral_radius_theo,color="blue",linewidth=2,alpha=0.4)
plt.plot(S,Spectral_radius_theo_hetero,color="red",linewidth=2,alpha=0.4)
plt.plot(S,np.ones(len(S)),color='k',linestyle="--")
plt.ylim(0,15,5)
plt.show()




T=5000
time=np.arange(0,T,1)
#environmental perturbations
perturbations = np.zeros(len(time))
filtered_noise_1 = np.zeros(len(time))
filtered_noise_2 =  np.zeros(len(time))
filtered_noise_3 =  np.zeros(len(time))
Noise=0.1
for t in range(len(time)-1):
  perturbations[t+1] = perturbations[t]+dt*(-perturbations[t]+filtered_noise_1[t])
  filtered_noise_1[t+1]= filtered_noise_1[t]+dt*0.1*(-1*filtered_noise_1[t]+filtered_noise_2[t])
  filtered_noise_2[t+1]= filtered_noise_2[t]+dt*0.1*(-1*filtered_noise_2[t]+filtered_noise_3[t])
  filtered_noise_3[t+1]= filtered_noise_3[t]+dt*(-1*filtered_noise_3[t])+np.sqrt(2*Noise*dt)*np.random.normal(0,1)

Spectral_radius_in_time = np.zeros(len(time))
Spectral_radius_theo_in_time =  np.zeros(len(time))
Spectral_radius_theo_in_time_hetero =np.zeros(len(time))
for t in range(len(time)):
  J_o = np.zeros((N,N))
  for i in range(N):
    for j in range(N):
      J_o[i][j] = W[i][j]*beta/np.sqrt(np.pi)*np.exp(-beta**2*(perturbations[t]+B)**2)
  Var_J_o = np.var(J_o)
  Spectral_radius_in_time[t] = np.sqrt(N*Var_J_o)
  Spectral_radius_theo_in_time[t] = np.sqrt(N*sigma_2*beta**2/(np.pi*np.sqrt(4*0*beta**2+1))*(np.exp(-beta**2*(perturbations[t]+B)**2))**2)
  Spectral_radius_theo_in_time_hetero[t] = np.sqrt(N*sigma_2*beta**2/(np.pi*np.sqrt(4*sigma_h*beta**2+1))*np.exp(-2*beta**2*(perturbations[t]+B)**2/(1+4*beta**2*sigma_h)))
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(time,Spectral_radius_in_time,color="blue",linewidth=4)
plt.plot(time,Spectral_radius_theo_in_time,color="blue",linewidth=2,alpha=0.4)
plt.plot(time,Spectral_radius_theo_in_time_hetero,color="red",linewidth=2,alpha=0.4)
plt.plot(time,np.ones(len(time)),color='k',linestyle="--")
plt.ylim(0,15,5)
plt.show()
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(time,perturbations,color='red')
plt.ylim(-0.4,0.4,0.1)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(S,Spectral_radius,color="black",linewidth=4)
plt.plot(S,Spectral_radius_theo,color="black",linewidth=2,alpha=0.4)
plt.plot(S,np.ones(len(S)),color='k',linestyle="--")
plt.ylim(0,12,4)
# plt.xlim(-0.1,0.1)
plt.show()

plt.figure(figsize=(10,5))
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(time,Spectral_radius_in_time,color="black",linewidth=4)
plt.plot(time,Spectral_radius_theo_in_time,color="black",linewidth=2,alpha=0.4)
plt.plot(time,np.ones(len(time)),color='k',linestyle="--")
plt.ylim(0,12,4)
# figure = plt.gca()
# x_axis = figure.axes.get_xaxis()
# x_axis.set_visible(False)
plt.xlim(0,2000)
plt.show()

plt.figure(figsize=(10,2))
plt.rcParams.update({'font.size': 22})
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.tick_params(axis='y', which='both', colors='red',labelleft=False, labelright=True)
plt.tick_params(axis="y", colors="red")
plt.plot(time,perturbations,color='red')
plt.plot(time,np.zeros(len(time)),color='red',linestyle='-',alpha=0.4)
plt.ylim(-0.25,0.25,0.1)
plt.xlim(0,2000)
figure = plt.gca()
x_axis = figure.axes.get_xaxis()
x_axis.set_visible(False)

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import special
from scipy.stats import norm
from scipy.stats import pearsonr
from scipy import signal
from scipy.fft import fftshift
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import MaxNLocator

import networkx as nx
import numpy as np
import pandas as pd


f=0.8#proportion of e vs i cells/cortical
sigma_e_2 = 0.005
sigma_i_2 = 0.005
N_o=100
beta_o=50
rho_o=0.05
mu_o=0.08
sigma_h=0
B=0.0

rho = np.arange(0,1.01,0.01)
N = np.arange(0,10100,100) 
mu = np.arange(0,1.01,0.01)
beta=np.arange(0,101,1)
sigma_ei=np.arange(0,0.0101,0.0001)
norm = np.arange(0,1.01,1.01/(len(rho)))
print(len(norm))

Gamma_rho =  np.sqrt(N_o*rho*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*(mu_o)**2)*beta_o**2/(np.pi*np.sqrt(4*0*beta_o**2+1))*np.exp(-2*beta_o**2*B**2/(1+4*beta_o**2*0)))
Gamma_N =  np.sqrt(N*rho_o*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*(mu_o)**2)*beta_o**2/(np.pi*np.sqrt(4*0*beta_o**2+1))*np.exp(-2*beta_o**2*B**2/(1+4*beta_o**2*0)))
Gamma_beta =  np.sqrt(N_o*rho_o*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*(mu_o)**2)*beta**2/(np.pi*np.sqrt(4*0*beta**2+1))*np.exp(-2*beta**2*B**2/(1+4*beta**2*0)))
Gamma_mu =  np.sqrt(N_o*rho_o*(f*sigma_e_2+(1-f)*sigma_i_2+f/(1-f)*(mu)**2)*beta_o**2/(np.pi*np.sqrt(4*0*beta_o**2+1))*np.exp(-2*beta_o**2*B**2/(1+4*beta_o**2*0)))
Gamma_sigmaei =  np.sqrt(N_o*rho_o*(f*sigma_ei+(1-f)*sigma_ei+f/(1-f)*(mu_o)**2)*beta_o**2/(np.pi*np.sqrt(4*0*beta_o**2+1))*np.exp(-2*beta_o**2*B**2/(1+4*beta_o**2*0)))



plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(10,5))
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(norm, Gamma_rho, color='orange')
plt.plot(norm, Gamma_N, color = "cyan")
plt.plot(norm, Gamma_beta, color='green')
plt.plot(norm, Gamma_mu, color='red')
plt.plot(norm, np.ones(len(rho)), color="black", linestyle='--')
# plt.plot(norm, Gamma_sigmaei)
plt.yscale("log")
plt.show()
plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(10,5))
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(rho, Gamma_rho, color='orange')
plt.xticks(color='orange')
plt.ylim(0,0.1)
plt.show()


plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(10,5))
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(N, Gamma_N, color = "cyan")
plt.xticks(color='cyan')
plt.ylim(0,0.1)
plt.show()

plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(10,5))
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(beta, Gamma_beta, color='green')
plt.xticks(color='green')
plt.ylim(0,0.1)
plt.show()

plt.rcParams.update({'font.size': 22})
plt.figure(figsize=(10,5))
for pos in ['right', 'top', 'bottom', 'left']:
   plt.gca().spines[pos].set_visible(False)
plt.plot(norm, Gamma_mu, color='red')
plt.xticks(color='red')
plt.ylim(0,0.1)
plt.show()



plt.show()
# Out:
# 101
